# %%
import matplotlib.pyplot as plt
import pandas as pd
import os

# Print current working directory
print("Current working directory:", os.getcwd())

# Load data using pandas
df = pd.read_csv("Vp-t.csv", delimiter=",", header=None)

# Extract columns
t = df.iloc[:, 0]  # First column (time)
y = df.iloc[:, 1]  # Second column (value)

# Plot
plt.figure(figsize=(8, 5))
plt.plot(t, y, marker="o", linestyle="-", color="b", markersize=3)

# Labels and Title
plt.xlabel("Time (t)")
plt.ylabel("Vp")
plt.grid(True)

# Show plot
plt.show()
# Out:
# Current working directory: /home/linux/Chemtest/ChemPlasKin/examples/Air

# %%
import matplotlib.pyplot as plt
import pandas as pd
import os

# Print current working directory
print("Current working directory:", os.getcwd())

# Load data using pandas
df = pd.read_csv("ne-t.csv", delimiter=",", header=None)

# Extract columns
t = df.iloc[:, 0]  # First column (time)
y = df.iloc[:, 1]  # Second column (value)

# Plot
plt.figure(figsize=(8, 5))
plt.plot(t, y, marker="o", linestyle="-", color="b", markersize=3)

# Labels and Title
plt.xlabel("Time (t)")
plt.ylabel("Vp")
plt.grid(True)

# Show plot
plt.show()
# Out:
# Current working directory: /home/linux/Chemtest/ChemPlasKin/examples/Air

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the CSV file into a DataFrame
df = pd.read_csv("outputAir.csv")
df.columns = [col.strip() for col in df.columns]

# List of species to plot
species = ["O", "N2(A3)", "N2(C3)"]

# Create the plot
fig, ax1 = plt.subplots()

# Plot each species
for specie in species:
    ax1.plot(1E9*df["Time(s)"], df[specie], label=specie)

# Add labels and title
ax1.set_xlabel("Time [ns]")
ax1.set_ylabel("Number Density [$\mathrm{\#/cm^3]}$")
ax1.set_yscale("log")  
# ax1.set_ylim(1E12, 1E19)
ax1.legend(loc='lower center')

ax2 = ax1.twinx()
ax2.plot(1E9*df["Time(s)"], df["T_gas(K)"], label="Temeprature", color='r')
ax2.set_ylabel("Temeprature [K]")
ax2.legend(loc='center right')

plt.grid(True)

# Show the plot
# plt.savefig("species_density.png", dpi=300, bbox_inches='tight')
plt.show()
# Out:
# <>:20: SyntaxWarning: invalid escape sequence '\m'
# <>:20: SyntaxWarning: invalid escape sequence '\m'
# /tmp/ipykernel_20464/588334867.py:20: SyntaxWarning: invalid escape sequence '\m'
#   ax1.set_ylabel("Number Density [$\mathrm{\#/cm^3]}$")
